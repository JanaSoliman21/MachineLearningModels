# %% [markdown]
# # 1. Importing packages

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelEncoder , MinMaxScaler
from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense

from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, classification_report

# %% [markdown]
# # 2. Loading The Dataset

# %% [markdown]
# ### Notice that we've changed the order of the data

# %%
dataC = pd.read_csv("/kaggle/input/breast-cancer-wisconsin-data/data.csv", encoding = "ISO-8859-1")
dataC = dataC.sample(n = len(dataC), random_state = 250)
dataC.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 10   845636         M        16.02         23.24          102.70      797.8
# 508  915452         B        16.30         15.70          104.70      819.8
# 482  912519         B        13.47         14.06           87.32      546.3
# 149  869931         B        13.74         17.91           88.12      585.0
# 67   859465         B        11.31         19.04           71.80      394.1
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 10           0.08206           0.06669         0.03299              0.03323
# 508          0.09427           0.06712         0.05526              0.04563
# 482          0.10710           0.11550         0.05786              0.05266
# 149          0.07944           0.06376         0.02881              0.01329
# 67           0.08139           0.04701         0.03709              0.02230
#
#      ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 10   ...          33.88           123.80      1150.0           0.11810
# 508  ...          17.76           109.80       928.2           0.13540
# 482  ...          18.32            94.94       660.2           0.13930
# 149  ...          22.46            97.19       725.9           0.09711
# 67   ...          23.84            78.00       466.7           0.12900
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 10             0.15510           0.1459               0.09975          0.2948
# 508            0.13610           0.1947               0.13570          0.2300
# 482            0.24990           0.1848               0.13350          0.3227
# 149            0.18240           0.1564               0.06019          0.2350
# 67             0.09148           0.1444               0.06961          0.2400
#
#      fractal_dimension_worst  Unnamed: 32
# 10                   0.08452          NaN
# 508                  0.07230          NaN
# 482                  0.09326          NaN
# 149                  0.07014          NaN
# 67                   0.06641          NaN
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Getting the dataset info is a good practice !

# %%
dataC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 569 entries, 10 to 218
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
#  32  Unnamed: 32              0 non-null      float64
# dtypes: float64(31), int64(1), object(1)
# memory usage: 151.1+ KB

# %% [markdown]
# # 3. Data Preprocessing

# %% [markdown]
# ### Drop what u won't need

# %%
dataC.drop(columns = ['id', 'Unnamed: 32'], inplace = True)
dataC.head()
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 10          M        16.02         23.24          102.70      797.8
# 508         B        16.30         15.70          104.70      819.8
# 482         B        13.47         14.06           87.32      546.3
# 149         B        13.74         17.91           88.12      585.0
# 67          B        11.31         19.04           71.80      394.1
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 10           0.08206           0.06669         0.03299              0.03323
# 508          0.09427           0.06712         0.05526              0.04563
# 482          0.10710           0.11550         0.05786              0.05266
# 149          0.07944           0.06376         0.02881              0.01329
# 67           0.08139           0.04701         0.03709              0.02230
#
#      symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 10          0.1528  ...         19.19          33.88           123.80
# 508         0.1711  ...         17.32          17.76           109.80
# 482         0.1779  ...         14.83          18.32            94.94
# 149         0.1473  ...         15.34          22.46            97.19
# 67          0.1516  ...         12.33          23.84            78.00
#
#      area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 10       1150.0           0.11810            0.15510           0.1459
# 508       928.2           0.13540            0.13610           0.1947
# 482       660.2           0.13930            0.24990           0.1848
# 149       725.9           0.09711            0.18240           0.1564
# 67        466.7           0.12900            0.09148           0.1444
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 10                0.09975          0.2948                  0.08452
# 508               0.13570          0.2300                  0.07230
# 482               0.13350          0.3227                  0.09326
# 149               0.06019          0.2350                  0.07014
# 67                0.06961          0.2400                  0.06641
#
# [5 rows x 31 columns]

# %% [markdown]
# ### Notice that 'diagnosis' column is from type object

# %% [markdown]
# * To solve this problem u need to transform it into numbers
# * The best solution is to transform it into zeros and ones

# %%
le = preprocessing.LabelEncoder()
dataC['diagnosis'] = le.fit_transform(dataC['diagnosis'])
dataC['diagnosis'].unique()
# Out:
# array([1, 0])

# %% [markdown]
# ### Let's look at the data again !

# %%
dataC.head()
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 10           1        16.02         23.24          102.70      797.8
# 508          0        16.30         15.70          104.70      819.8
# 482          0        13.47         14.06           87.32      546.3
# 149          0        13.74         17.91           88.12      585.0
# 67           0        11.31         19.04           71.80      394.1
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 10           0.08206           0.06669         0.03299              0.03323
# 508          0.09427           0.06712         0.05526              0.04563
# 482          0.10710           0.11550         0.05786              0.05266
# 149          0.07944           0.06376         0.02881              0.01329
# 67           0.08139           0.04701         0.03709              0.02230
#
#      symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 10          0.1528  ...         19.19          33.88           123.80
# 508         0.1711  ...         17.32          17.76           109.80
# 482         0.1779  ...         14.83          18.32            94.94
# 149         0.1473  ...         15.34          22.46            97.19
# 67          0.1516  ...         12.33          23.84            78.00
#
#      area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 10       1150.0           0.11810            0.15510           0.1459
# 508       928.2           0.13540            0.13610           0.1947
# 482       660.2           0.13930            0.24990           0.1848
# 149       725.9           0.09711            0.18240           0.1564
# 67        466.7           0.12900            0.09148           0.1444
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 10                0.09975          0.2948                  0.08452
# 508               0.13570          0.2300                  0.07230
# 482               0.13350          0.3227                  0.09326
# 149               0.06019          0.2350                  0.07014
# 67                0.06961          0.2400                  0.06641
#
# [5 rows x 31 columns]

# %% [markdown]
# ### Prepare ur features (x) and labels (y)

# %%
x = dataC.drop(columns = ['diagnosis'])
y = dataC[['diagnosis']]

# %% [markdown]
# ### Checking their shapes is a good practice to solve many problems to come

# %%
print(y.shape)
print(x.shape)
# Out:
# (569, 1)
# (569, 30)

# %% [markdown]
# ### Normalize ur features and labels

# %% [markdown]
# This step makes a huge difference in ur models accuracy !

# %%
scaler = MinMaxScaler()
x = scaler.fit_transform(x)
y = scaler.fit_transform(y)

# %% [markdown]
# ### Split ur features and labels

# %% [markdown]
# This step helps to save some data without training the model on it

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.30, random_state = 42)

# %% [markdown]
# # 4. Create Your Models

# %% [markdown]
# ## 1. The ANN Model

# %% [markdown]
# ## Creating the Model (Model Structure)

# %%
modelANN_classification = Sequential([
                                         Dense(10, activation = 'relu', input_dim = 30),
                                         Dense(15, activation = 'relu'),
                                         Dense(1, activation = 'linear')
                                     ])
modelANN_classification.compile(optimizer = 'adam', loss = 'mean_squared_error')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:85: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ## Checking on it

# %%
modelANN_classification.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_9 (Dense)                 │ (None, 10)             │           310 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 15)             │           165 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │            16 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 491 (1.92 KB)
#  Trainable params: 491 (1.92 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Training it

# %%
history = modelANN_classification.fit(x_train, y_train, epochs = 100, validation_split = 0.2)
# Out:
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.1186 - val_loss: 0.6969
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6837 - val_loss: 0.4761
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5045 - val_loss: 0.3322
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3019 - val_loss: 0.2464
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2396 - val_loss: 0.2035
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1955 - val_loss: 0.1892
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1831 - val_loss: 0.1854
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1710 - val_loss: 0.1826
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1736 - val_loss: 0.1780
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1682 - val_loss: 0.1730
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1631 - val_loss: 0.1670
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1539 - val_loss: 0.1607
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1506 - val_loss: 0.1549
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1462 - val_loss: 0.1500
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1434 - val_loss: 0.1435
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1399 - val_loss: 0.1371
# Epoch 17/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1310 - val_loss: 0.1306
# Epoch 18/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1223 - val_loss: 0.1247
# Epoch 19/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1189 - val_loss: 0.1180
# Epoch 20/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1055 - val_loss: 0.1115
# Epoch 21/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1089 - val_loss: 0.1040
# Epoch 22/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1018 - val_loss: 0.0975
# Epoch 23/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0909 - val_loss: 0.0910
# Epoch 24/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0874 - val_loss: 0.0858
# Epoch 25/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0867 - val_loss: 0.0803
# Epoch 26/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0814 - val_loss: 0.0746
# Epoch 27/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0848 - val_loss: 0.0705
# Epoch 28/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0810 - val_loss: 0.0667
# Epoch 29/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0694 - val_loss: 0.0632
# Epoch 30/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0718 - val_loss: 0.0621
# Epoch 31/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0629 - val_loss: 0.0583
# Epoch 32/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0707 - val_loss: 0.0582
# Epoch 33/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0645 - val_loss: 0.0549
# Epoch 34/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0673 - val_loss: 0.0546
# Epoch 35/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0643 - val_loss: 0.0527
# Epoch 36/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0633 - val_loss: 0.0514
# Epoch 37/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0585 - val_loss: 0.0513
# Epoch 38/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0597 - val_loss: 0.0498
# Epoch 39/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0571 - val_loss: 0.0497
# Epoch 40/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0572 - val_loss: 0.0494
# Epoch 41/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0567 - val_loss: 0.0486
# Epoch 42/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0548 - val_loss: 0.0485
# Epoch 43/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0535 - val_loss: 0.0487
# Epoch 44/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0576 - val_loss: 0.0466
# Epoch 45/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0516 - val_loss: 0.0470
# Epoch 46/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0559 - val_loss: 0.0473
# Epoch 47/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0534 - val_loss: 0.0459
# Epoch 48/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0534 - val_loss: 0.0469
# Epoch 49/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0519 - val_loss: 0.0467
# Epoch 50/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0484 - val_loss: 0.0457
# Epoch 51/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0523 - val_loss: 0.0458
# Epoch 52/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0517 - val_loss: 0.0466
# Epoch 53/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0484 - val_loss: 0.0450
# Epoch 54/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0499 - val_loss: 0.0447
# Epoch 55/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0520 - val_loss: 0.0446
# Epoch 56/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0526 - val_loss: 0.0448
# Epoch 57/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0497 - val_loss: 0.0441
# Epoch 58/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0486 - val_loss: 0.0435
# Epoch 59/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0436 - val_loss: 0.0442
# Epoch 60/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0427 - val_loss: 0.0434
# Epoch 61/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0450 - val_loss: 0.0435
# Epoch 62/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0445 - val_loss: 0.0426
# Epoch 63/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0418 - val_loss: 0.0423
# Epoch 64/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0441 - val_loss: 0.0430
# Epoch 65/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0469 - val_loss: 0.0413
# Epoch 66/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0440 - val_loss: 0.0426
# Epoch 67/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0458 - val_loss: 0.0416
# Epoch 68/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0470 - val_loss: 0.0413
# Epoch 69/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0429 - val_loss: 0.0417
# Epoch 70/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0481 - val_loss: 0.0406
# Epoch 71/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0403 - val_loss: 0.0412
# Epoch 72/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0423 - val_loss: 0.0409
# Epoch 73/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0417 - val_loss: 0.0407
# Epoch 74/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0419 - val_loss: 0.0406
# Epoch 75/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0429 - val_loss: 0.0412
# Epoch 76/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0395 - val_loss: 0.0401
# Epoch 77/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0335 - val_loss: 0.0401
# Epoch 78/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0467 - val_loss: 0.0406
# Epoch 79/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0380 - val_loss: 0.0395
# Epoch 80/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0435 - val_loss: 0.0402
# Epoch 81/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0438 - val_loss: 0.0400
# Epoch 82/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0389 - val_loss: 0.0397
# Epoch 83/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0417 - val_loss: 0.0397
# Epoch 84/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0347 - val_loss: 0.0393
# Epoch 85/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0442 - val_loss: 0.0396
# Epoch 86/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0395 - val_loss: 0.0391
# Epoch 87/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0437 - val_loss: 0.0396
# Epoch 88/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0394 - val_loss: 0.0394
# Epoch 89/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0366 - val_loss: 0.0392
# Epoch 90/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0355 - val_loss: 0.0396
# Epoch 91/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0358 - val_loss: 0.0392
# Epoch 92/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0378 - val_loss: 0.0388
# Epoch 93/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0388 - val_loss: 0.0402
# Epoch 94/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0398 - val_loss: 0.0385
# Epoch 95/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0308 - val_loss: 0.0394
# Epoch 96/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0401 - val_loss: 0.0384
# Epoch 97/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0374 - val_loss: 0.0389
# Epoch 98/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0385 - val_loss: 0.0385
# Epoch 99/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0361 - val_loss: 0.0386
# Epoch 100/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0334 - val_loss: 0.0392

# %% [markdown]
# ## Plotting its results

# %%
tr_loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]

Epochs = [i + 1 for i in range(len(tr_loss))]

loss_label = f"best epoch = {index_loss}"

plt.figure(figsize = (20, 8))

plt.plot(Epochs, tr_loss, "r", label = "Training Loss")
plt.plot(Epochs, val_loss, "g", label = "Validation Loss")

plt.scatter(index_loss + 1, val_lowest, c = "black", s = 150, label = loss_label)

plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.show()

# %% [markdown]
# ## Prediction

# %%
y_hatANN = modelANN_classification.predict(x_test)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %% [markdown]
# ## Error Rate

# %%
print(mean_squared_error(y_test, y_hatANN))
# Out:
# 0.04711495069129249

# %% [markdown]
# ## Models Score

# %%
print(r2_score(y_test, y_hatANN))
# Out:
# 0.7961396458768742

# %% [markdown]
# ## 2. KNN Model

# %% [markdown]
# ### Creating the Model

# %%
modelKNN_classification = KNeighborsClassifier(n_neighbors = 9, metric = 'l2')

# %% [markdown]
# ### Training it

# %%
modelKNN_classification.fit(x_train, y_train)
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier(metric='l2', n_neighbors=9)

# %% [markdown]
# ### Prediction

# %%
y_hatKNN = modelKNN_classification.predict(x_test)

# %% [markdown]
# ### Model's Score

# %%
accuracy_score(y_test, y_hatKNN)
# Out:
# 0.9649122807017544

# %% [markdown]
# ## 3. Logistic Regression

# %% [markdown]
# ### Creating the model

# %%
modelRegression_classification = LogisticRegression()

# %% [markdown]
# ### Training it

# %%
modelRegression_classification.fit(x_train, y_train)
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %% [markdown]
# ### Prediction

# %%
y_hatRegression = modelRegression_classification.predict(x_test)

# %% [markdown]
# ### Creating the Confusion Matrix

# %%
cf_matrix = confusion_matrix(y_test, y_hatRegression)
cf_matrix
# Out:
# array([[108,   1],
#        [  9,  53]])

# %% [markdown]
# ### Visualizing the Confusion Matrix

# %%
sns.heatmap(pd.DataFrame(cf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 23.52222222222222, 'Predicted label')

# %% [markdown]
# ### Model's Score

# %%
accuracy_score(y_test, y_hatRegression)
# Out:
# 0.9415204678362573
